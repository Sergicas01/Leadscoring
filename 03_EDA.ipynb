# %% [markdown]
# # EDA

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/sergi/Desktop/DATA/CURSO DS4B/EstructuraDirectorio/03_MACHINE_LEARNING/08_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_cat = 'cat_resultado_calidad.pickle'
nombre_num = 'num_resultado_calidad.pickle'

# %% [markdown]
# Cargar los datos.

# %%
cat = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_cat)
num = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_num)

# %% [markdown]
# ## EDA CATEGÓRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def frecuencias_cat(df_cat):
    resultado = df_cat.apply(lambda x: x.value_counts(normalize = True)).T.stack()\
                .to_frame().reset_index()\
                .rename(columns={'level_0':'Variable','level_1':'Valor',0: "Frecuencia"})\
                .sort_values(by = ['Variable','Frecuencia'])
    return(resultado)

# %%
frecuencias_cat(cat)
# Out:
#                  Variable                              Valor  Frecuencia
# 27                 ambito             International Business    0.024474
# 29                 ambito              Media and Advertising    0.025422
# 34                 ambito                 Travel and Tourism    0.026181
# 22                 ambito  Banking, Investment And Insurance    0.042497
# 33                 ambito            Supply Chain Management    0.047619
# 26                 ambito             IT Projects Management    0.050465
# 23                 ambito            Business Administration    0.050844
# 31                 ambito              Operations Management    0.068678
# 30                 ambito                              OTROS    0.085563
# 28                 ambito               Marketing Management    0.101499
# 25                 ambito          Human Resource Management    0.107759
# 24                 ambito                 Finance Management    0.120470
# 32                 ambito                             Select    0.248530
# 44     conociste_facebook                              OTROS    0.000759
# 43     conociste_facebook                                 No    0.999241
# 40       conociste_google                              OTROS    0.001707
# 39       conociste_google                                 No    0.998293
# 42    conociste_periodico                              OTROS    0.000190
# 41    conociste_periodico                                 No    0.999810
# 46  conociste_referencias                              OTROS    0.001138
# 45  conociste_referencias                                 No    0.998862
# 48            descarga_lm                                Yes    0.388541
# 47            descarga_lm                                 No    0.611459
# 7                  fuente                              OTROS    0.028078
# 9                  fuente                          Reference    0.044963
# 4                  fuente                               Chat    0.059382
# 8                  fuente                     Organic Search    0.152343
# 5                  fuente                     Direct Traffic    0.343009
# 6                  fuente                             Google    0.372225
# 11        no_enviar_email                                Yes    0.088788
# 10        no_enviar_email                                 No    0.911212
# 13              no_llamar                              OTROS    0.000379
# 12              no_llamar                                 No    0.999621
# 35              ocupacion                              OTROS    0.004933
# 36              ocupacion                            Student    0.024853
# 38              ocupacion               Working Professional    0.082906
# 37              ocupacion                         Unemployed    0.887308
# 3                  origen                              OTROS    0.006450
# 2                  origen                      Lead Add Form    0.048188
# 0                  origen                                API    0.303168
# 1                  origen            Landing Page Submission    0.642193
# 17          ult_actividad                 Email Link Clicked    0.027509
# 16          ult_actividad                      Email Bounced    0.037374
# 14          ult_actividad                  Chat Conversation    0.051793
# 19          ult_actividad                              OTROS    0.052362
# 15          ult_actividad                  Converted to Lead    0.055208
# 20          ult_actividad            Page Visited on Website    0.082906
# 21          ult_actividad                           SMS Sent    0.309808
# 18          ult_actividad                       Email Opened    0.383039

# %%
cat.shape
# Out:
# (5271, 12)

# %%
cat = cat.loc[(cat.no_llamar != 'OTROS') & (cat.no_enviar_email != 'Yes') & (cat.ult_actividad != 'Email Bounced')].drop(columns = ['conociste_facebook',
                                                                                                                             'conociste_google',
                                                                                                                             'conociste_periodico',
                                                                                                                             'conociste_referencias',
                                                                                                                             'no_enviar_email',
                                                                                                                             'no_llamar'])

# %%
cat.shape
# Out:
# (4792, 6)

# %%
num = num[num.index.isin(cat.index)]

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_categoricos(cat):
    
    #Calculamos el número de filas que necesitamos
    from math import ceil
    filas = ceil(cat.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        cat[variable].value_counts().plot.barh(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_categoricos(cat)

# %% [markdown]
# ## EDA NUMÉRICAS

# %% [markdown]
# ### Análisis estadístico

# %%
def estadisticos_cont(num):
    #Calculamos describe
    estadisticos = num.describe().T
    #Añadimos la mediana
    estadisticos['median'] = num.median()
    #Reordenamos para que la mediana esté al lado de la media
    estadisticos = estadisticos.iloc[:,[0,1,8,2,3,4,5,6,7]]
    #Lo devolvemos
    return(estadisticos)

# %%
estadisticos_cont(num)
# Out:
#                         count        mean  median         std   min    25%  \
# compra                 4792.0    0.419866     0.0    0.493588   0.0    0.0
# visitas_total          4792.0    4.132721     3.0     3.47996   0.0    2.0
# tiempo_en_site_total   4792.0  613.185518   374.0  558.010015   0.0  131.0
# paginas_vistas_visita  4792.0    2.872064    2.45    1.908554   0.0    2.0
# score_actividad        4792.0   14.058013    14.0    0.945595   7.0   14.0
# score_perfil           4792.0   16.304257    16.0    1.420134  11.0   16.0
#
#                          50%      75%     max
# compra                   0.0      1.0     1.0
# visitas_total            3.0      5.0    50.0
# tiempo_en_site_total   374.0  1106.25  2272.0
# paginas_vistas_visita   2.45      4.0    20.0
# score_actividad         14.0     14.0    18.0
# score_perfil            16.0     17.0    20.0

# %% [markdown]
# ### Análisis gráfico

# %%
def graficos_eda_continuas(num):
    
    #Calculamos el número de fila que necesitamos
    from math import ceil
    filas = ceil(num.shape[1] / 2)

    #Definimos el gráfico
    f, ax = plt.subplots(nrows = filas, ncols = 2, figsize = (16, filas * 6))

    #Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat 

    #Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(num):
        num[variable].plot.density(ax = ax[cada])
        ax[cada].set_title(variable, fontsize = 12, fontweight = "bold")
        ax[cada].tick_params(labelsize = 12)

# %%
graficos_eda_continuas(num)

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.
#
# *NOTA: En algunos casos no hay cambios en los ficheros en esta fase, así que este paso es opcional.Pero si no guardas estos ficheros acuérdate de modificar la importación en el siguiente notebook.*

# %%
#Definir los nombres de los archivos
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_eda.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_eda.pickle'

# %%
#Guardar los archivos
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
