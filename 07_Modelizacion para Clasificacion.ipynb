# %% [markdown]
# # MODELIZACIÓN PARA CLASIFICACIÓN

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.metrics import classification_report

#from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
import scikitplot as skplt
#from yellowbrick.classifier import discrimination_threshold

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/sergi/Desktop/DATA/CURSO DS4B/EstructuraDirectorio/03_MACHINE_LEARNING/08_CASOS/01_LEADSCORING'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_x = 'x_preseleccionado.pickle'
nombre_y = 'y_preseleccionado.pickle'

# %% [markdown]
# Cargar los datos.

# %%
x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %% [markdown]
# Modificar para dejar solo los algoritmos que se quieran testar.
#
# Modificar los parámetros.

# %%
pipe = Pipeline([('algoritmo',RandomForestClassifier())])

grid = [{'algoritmo': [LogisticRegression()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__solver': ['saga'],
         'algoritmo__penalty': ['elasticnet', 'l1', 'l2', 'none'],
         'algoritmo__C': [0,0.25,0.5,0.75,1]}
       ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# Elegir si se quiere usar grid search o random search.
#
# Comentar la opción que no se vaya a usar.

# %% [markdown]
# ####  Con grid search

# %%
grid_search = GridSearchCV(estimator= pipe, 
                            param_grid = grid, 
                            cv = 3, 
                            scoring = 'roc_auc',
                            verbose = 0,
                            n_jobs = -1)

modelo = grid_search.fit(train_x,train_y)

pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 19           0.04          0.00             0.00            0.00
# 7            0.05          0.01             0.01            0.00
# 15           0.04          0.00             0.01            0.00
# 11           0.05          0.01             0.01            0.00
# 17           0.05          0.01             0.01            0.00
# 13           0.05          0.01             0.01            0.00
# 9            0.04          0.00             0.01            0.00
# 18           0.03          0.00             0.01            0.00
# 14           0.04          0.01             0.01            0.00
# 5            0.05          0.01             0.01            0.00
# 10           0.03          0.00             0.01            0.00
# 6            0.04          0.01             0.01            0.00
# 8            0.00          0.00             0.00            0.00
# 4            0.00          0.00             0.00            0.00
# 12           0.00          0.00             0.00            0.00
# 3            0.00          0.00             0.00            0.00
# 2            0.00          0.00             0.00            0.00
# 16           0.00          0.00             0.00            0.00
# 1            0.00          0.00             0.00            0.00
# 0            0.00          0.00             0.00            0.00
#
#          param_algoritmo param_algoritmo__C param_algoritmo__n_jobs  \
# 19  LogisticRegression()                  1                      -1
# 7   LogisticRegression()               0.25                      -1
# 15  LogisticRegression()               0.75                      -1
# 11  LogisticRegression()               0.50                      -1
# 17  LogisticRegression()                  1                      -1
# 13  LogisticRegression()               0.75                      -1
# 9   LogisticRegression()               0.50                      -1
# 18  LogisticRegression()                  1                      -1
# 14  LogisticRegression()               0.75                      -1
# 5   LogisticRegression()               0.25                      -1
# 10  LogisticRegression()               0.50                      -1
# 6   LogisticRegression()               0.25                      -1
# 8   LogisticRegression()               0.50                      -1
# 4   LogisticRegression()               0.25                      -1
# 12  LogisticRegression()               0.75                      -1
# 3   LogisticRegression()                  0                      -1
# 2   LogisticRegression()                  0                      -1
# 16  LogisticRegression()                  1                      -1
# 1   LogisticRegression()                  0                      -1
# 0   LogisticRegression()                  0                      -1
#
#    param_algoritmo__penalty param_algoritmo__solver  \
# 19                     none                    saga
# 7                      none                    saga
# 15                     none                    saga
# 11                     none                    saga
# 17                       l1                    saga
# 13                       l1                    saga
# 9                        l1                    saga
# 18                       l2                    saga
# 14                       l2                    saga
# 5                        l1                    saga
# 10                       l2                    saga
# 6                        l2                    saga
# 8                elasticnet                    saga
# 4                elasticnet                    saga
# 12               elasticnet                    saga
# 3                      none                    saga
# 2                        l2                    saga
# 16               elasticnet                    saga
# 1                        l1                    saga
# 0                elasticnet                    saga
#
#                                                params  split0_test_score  \
# 19  {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 7   {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 15  {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 11  {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 17  {'algoritmo': LogisticRegression(), 'algoritmo...               0.86
# 13  {'algoritmo': LogisticRegression(), 'algoritmo...               0.86
# 9   {'algoritmo': LogisticRegression(), 'algoritmo...               0.86
# 18  {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 14  {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 5   {'algoritmo': LogisticRegression(), 'algoritmo...               0.86
# 10  {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 6   {'algoritmo': LogisticRegression(), 'algoritmo...               0.85
# 8   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 4   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 12  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 3   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 2   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 16  {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 1   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
# 0   {'algoritmo': LogisticRegression(), 'algoritmo...                NaN
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 19               0.86               0.87             0.86            0.01
# 7                0.86               0.87             0.86            0.01
# 15               0.86               0.87             0.86            0.01
# 11               0.86               0.87             0.86            0.01
# 17               0.86               0.87             0.86            0.01
# 13               0.86               0.87             0.86            0.01
# 9                0.86               0.87             0.86            0.01
# 18               0.86               0.87             0.86            0.01
# 14               0.86               0.87             0.86            0.01
# 5                0.86               0.87             0.86            0.00
# 10               0.86               0.87             0.86            0.01
# 6                0.86               0.86             0.85            0.01
# 8                 NaN                NaN              NaN             NaN
# 4                 NaN                NaN              NaN             NaN
# 12                NaN                NaN              NaN             NaN
# 3                 NaN                NaN              NaN             NaN
# 2                 NaN                NaN              NaN             NaN
# 16                NaN                NaN              NaN             NaN
# 1                 NaN                NaN              NaN             NaN
# 0                 NaN                NaN              NaN             NaN
#
#     rank_test_score
# 19                1
# 7                 1
# 15                3
# 11                4
# 17                5
# 13                6
# 9                 7
# 18                8
# 14                9
# 5                10
# 10               11
# 6                12
# 8                13
# 4                13
# 12               13
# 3                13
# 2                13
# 16               13
# 1                13
# 0                13

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = modelo.best_estimator_.predict_proba(val_x)[:, 1]

# %% [markdown]
# ### Evaluar sobre validación

# %%
roc_auc_score(val_y, pred)
# Out:
# 0.8568461994857932

# %% [markdown]
# ### Examinar el mejor modelo

# %%
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  LogisticRegression(C=0.25, n_jobs=-1, penalty='none',
#                                     solver='saga'))])

# %%
pd.DataFrame(data = modelo.best_estimator_.named_steps.algoritmo.coef_,
            columns = modelo.best_estimator_.named_steps.algoritmo.feature_names_in_).unstack().sort_values(ascending= False)
# Out:
# score_actividad_mms                    0    9.19
# tiempo_en_site_total_mms               0    4.24
# ocupacion_Working Professional         0    2.21
# score_perfil_mms                       0    1.85
# ult_actividad_SMS Sent                 0    0.94
# descarga_lm_No                         0    0.91
# ambito_Marketing Management            0    0.23
# fuente_Google                          0   -0.46
# ambito_Select                          0   -0.49
# ocupacion_Unemployed                   0   -0.68
# ult_actividad_Page Visited on Website  0   -0.86
# ult_actividad_Chat Conversation        0   -1.16
# ult_actividad_Converted to Lead        0   -2.09
# paginas_vistas_visita_mms              0   -3.25
# dtype: float64

# %% [markdown]
# ## REPORTING DEL MODELO

# %% [markdown]
# ### Gain Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_cumulative_gain(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 

# Eliminamos la línea de los ceros, que internamente tiene etiqueta 'Class 0'
lines = ax.get_lines()
# Buscar por la etiqueta y eliminar la línea correspondiente
for line in lines:
    if line.get_label() == 'Class 0':
        line.remove()

# Personalizamos la leyenda sin incluir la línea de los ceros
plt.legend(labels=['Modelo'])

# Ahora puedes mostrar el gráfico
plt.show()

# %% [markdown]
# ### Lift Chart

# %%
fig, ax = plt.subplots()

skplt.metrics.plot_lift_curve(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax) 

# Eliminamos la línea de los ceros, que internamente tiene etiqueta 'Class 0'
lines = ax.get_lines()
# Buscar por la etiqueta y eliminar la línea correspondiente
for line in lines:
    if line.get_label() == 'Class 0':
        line.remove()

# Personalizamos la leyenda sin incluir la línea de los ceros
plt.legend(labels=['Modelo'])

# Ahora puedes mostrar el gráfico
plt.show()

# %% [markdown]
# ### ROC Chart

# %%
fig, ax = plt.subplots()

# Generamos la gráfica ROC
skplt.metrics.plot_roc(val_y, modelo.best_estimator_.predict_proba(val_x), ax=ax)

# Obtenemos todas las líneas y las leyendas
lines = ax.get_lines()

# Recorremos las líneas para eliminar las no deseadas, excepto la línea de la clase 0
for line in lines:
    if 'ROC curve of class 0' in line.get_label():
        line.set_label('Modelo')
    elif line.get_linestyle() != '--':  # Mantenemos la línea punteada pero sin leyenda
        line.set_visible(False)

# Solo añadimos al leyenda la línea de la clase 0 renombrada a 'Modelo'
handles, labels = ax.get_legend_handles_labels()
new_handles = [h for h, l in zip(handles, labels) if l == 'Modelo']
new_labels = ['Modelo']

ax.legend(new_handles, new_labels, loc='best')

# Ahora puedes mostrar el gráfico
plt.show();
